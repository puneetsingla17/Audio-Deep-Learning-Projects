# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import glob
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
import matplotlib.pyplot as plt
import os
print(os.listdir("../input"))
import tensorflow as tf
from keras.layers import Conv2D,Concatenate,Dense,Add,SpatialDropout2D,SeparableConv2D,Activation,Reshape,Bidirectional,Dropout,Multiply,LeakyReLU,Input,GlobalAveragePooling2D,BatchNormalization,Activation,ZeroPadding1D,Concatenate,Dropout,LSTM
from keras.models import Model,Sequential
from tqdm import tqdm_notebook
from keras.optimizers import Adam
import keras
# Any results you write to the current directory are saved as output.
# Out:
# ['train_noisy', 'sample_submission.csv', 'train_curated', 'train_curated.csv', 'train_noisy.csv', 'test']
# Using TensorFlow backend.

# %%
df=pd.read_csv("../input/train_curated.csv")

# %%
df.head()
# Out:
#           fname           labels
# 0  0006ae4e.wav             Bark
# 1  0019ef41.wav         Raindrop
# 2  001ec0ad.wav  Finger_snapping
# 3  0026c7cb.wav              Run
# 4  0026f116.wav  Finger_snapping

# %%
testdf=pd.read_csv("../input/sample_submission.csv")

# %%
label_columns=testdf.columns[1:]
labelmapping=dict((label,index) for index,label in enumerate(label_columns))
for col in label_columns:
    df[col]=0

# %%
labelmapping
# Out:
# {'Accelerating_and_revving_and_vroom': 0,
#  'Accordion': 1,
#  'Acoustic_guitar': 2,
#  'Applause': 3,
#  'Bark': 4,
#  'Bass_drum': 5,
#  'Bass_guitar': 6,
#  'Bathtub_(filling_or_washing)': 7,
#  'Bicycle_bell': 8,
#  'Burping_and_eructation': 9,
#  'Bus': 10,
#  'Buzz': 11,
#  'Car_passing_by': 12,
#  'Cheering': 13,
#  'Chewing_and_mastication': 14,
#  'Child_speech_and_kid_speaking': 15,
#  'Chink_and_clink': 16,
#  'Chirp_and_tweet': 17,
#  'Church_bell': 18,
#  'Clapping': 19,
#  'Computer_keyboard': 20,
#  'Crackle': 21,
#  'Cricket': 22,
#  'Crowd': 23,
#  'Cupboard_open_or_close': 24,
#  'Cutlery_and_silverware': 25,
#  'Dishes_and_pots_and_pans': 26,
#  'Drawer_open_or_close': 27,
#  'Drip': 28,
#  'Electric_guitar': 29,
#  'Fart': 30,
#  'Female_singing': 31,
#  'Female_speech_and_woman_speaking': 32,
#  'Fill_(with_liquid)': 33,
#  'Finger_snapping': 34,
#  'Frying_(food)': 35,
#  'Gasp': 36,
#  'Glockenspiel': 37,
#  'Gong': 38,
#  'Gurgling': 39,
#  'Harmonica': 40,
#  'Hi-hat': 41,
#  'Hiss': 42,
#  'Keys_jangling': 43,
#  'Knock': 44,
#  'Male_singing': 45,
#  'Male_speech_and_man_speaking': 46,
#  'Marimba_and_xylophone': 47,
#  'Mechanical_fan': 48,
#  'Meow': 49,
#  'Microwave_oven': 50,
#  'Motorcycle': 51,
#  'Printer': 52,
#  'Purr': 53,
#  'Race_car_and_auto_racing': 54,
#  'Raindrop': 55,
#  'Run': 56,
#  'Scissors': 57,
#  'Screaming': 58,
#  'Shatter': 59,
#  'Sigh': 60,
#  'Sink_(filling_or_washing)': 61,
#  'Skateboard': 62,
#  'Slam': 63,
#  'Sneeze': 64,
#  'Squeak': 65,
#  'Stream': 66,
#  'Strum': 67,
#  'Tap': 68,
#  'Tick-tock': 69,
#  'Toilet_flush': 70,
#  'Traffic_noise_and_roadway_noise': 71,
#  'Trickle_and_dribble': 72,
#  'Walk_and_footsteps': 73,
#  'Water_tap_and_faucet': 74,
#  'Waves_and_surf': 75,
#  'Whispering': 76,
#  'Writing': 77,
#  'Yell': 78,
#  'Zipper_(clothing)': 79}

# %%
def fun(x):
    a=np.zeros(80)
    for i in x.split(","):
        a[labelmapping[i]]=1
    return a

# %%
def labelling_training(rowlabels,nclasses):
    rows_label_list=[]
    for row in rowlabels:
        p=row.split(",")
        labelsarray=np.zeros((nclasses))
        for label in p:
            index=labelmapping[label]
            labelsarray[index]=1
        rows_label_list.append(labelsarray)
    return rows_label_list

# %%
df.head()
# Out:
#           fname           labels        ...          Yell  Zipper_(clothing)
# 0  0006ae4e.wav             Bark        ...             0                  0
# 1  0019ef41.wav         Raindrop        ...             0                  0
# 2  001ec0ad.wav  Finger_snapping        ...             0                  0
# 3  0026c7cb.wav              Run        ...             0                  0
# 4  0026f116.wav  Finger_snapping        ...             0                  0
#
# [5 rows x 82 columns]

# %%
df[label_columns]=labelling_training(df.labels,80)

# %%
df['numlabels']=df[label_columns].sum(axis=1)

# %%
audiodir1=glob.glob("../input/train_curated/*.wav")
audiodir2=glob.glob("../input/train_noisy/*.wav")

# %%
print(len(audiodir1))
print(len(audiodir2))
# Out:
# 4970
# 19815

# %%
import librosa

# %%
sr=26000
duration=9
hop_length=400
fmin=20
fmax=sr//2
n_mels=128
n_fft=n_mels*20
samples=sr*duration

# %%
def read_audio(path):
    '''
    Reads in the audio file and returns
    an array that we can turn into a melspectogram
    '''
    y, _ = librosa.core.load(path, sr=44100)
    # trim silence
    if 0 < len(y): # workaround: 0 length causes error
        y, _ = librosa.effects.trim(y)
    if len(y) > samples: # long enough
        y = y[0:0+samples]
    else: # pad blank
        padding = samples - len(y)
        offset = padding // 2
        y = np.pad(y, (offset, samples - len(y) - offset), 'constant')
    return y

def audio_to_melspectrogram(audio):
    '''
    Convert to melspectrogram after audio is read in
    '''
    spectrogram = librosa.feature.melspectrogram(audio, 
                                                 sr=sr,
                                                 n_mels=n_mels,
                                                 hop_length=hop_length,
                                                 n_fft=n_fft,
                                                 fmin=fmin,
                                                 fmax=fmax)
    return librosa.power_to_db(spectrogram).astype(np.float32)

def read_as_melspectrogram(path):
    '''
    Convert audio into a melspectrogram 
    so we can use machine learning
    '''
    mels = audio_to_melspectrogram(read_audio(path))
    return mels

def convert_wav_to_image(df, path):
    X = []
    for _,row in tqdm_notebook(df.iterrows()):
        x = read_as_melspectrogram('{}/{}'.format(path[0],
                                                  str(row['fname'])))
        X.append(x.transpose())
    return X

def normalize(img):
    '''
    Normalizes an array 
    (subtract mean and divide by standard deviation)
    '''
    eps = 0.001
    if np.std(img) != 0:
        img = (img - np.mean(img)) / np.std(img)
    else:
        img = (img - np.mean(img)) / eps
    return img

def normalize_dataset(X):
    '''
    Normalizes list of arrays
    (subtract mean and divide by standard deviation)
    '''
    normalized_dataset = []
    for img in X:
        normalized = normalize(img)
        normalized_dataset.append(normalized)
    return normalized_dataset

# %%
KAGGLE_DIR = '../input/'
train_curated_path = KAGGLE_DIR + 'train_curated/'
test_path = KAGGLE_DIR + 'test/'

# %%
from sklearn.model_selection import train_test_split

# %%
X = np.array(convert_wav_to_image(df, [train_curated_path]))
X = normalize_dataset(X)
Y = df[label_columns].values
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %%
x_train, x_val, y_train, y_val = train_test_split(X, Y, test_size=0.1, random_state=42)

# %%
y_train.shape
# Out:
# (4473, 80)

# %%
x_train[0].shape
# Out:
# (586, 128)

# %%
x_train=np.array(x_train)
x_val=np.array(x_val)

# %%
x_train=x_train.astype('float16')
x_val=x_val.astype('float16')

# %%
X=np.array(1)
Y=np.array(1)

# %%
x_train=x_train.reshape((-1,586,128,1))

# %%
x_train.shape
# Out:
# (4473, 586, 128, 1)

# %%
input_shape=(586,128,1)
optimizer=Adam(0.008,beta_1=1.0,beta_2=0.001,amsgrad=True)
n_classes=80

# %%
params_conv2d = {
        "padding": "SAME",
        "activation": keras.activations.elu
        # 'kernel_regularizer': keras.regularizers.l2(0.01)
}

# %%
def spatial_squeeze_excite_block(input1):
    se=Conv2D(1,(1,1),activation='sigmoid',kernel_initializer='he_normal')(input1)
    x=Multiply()([input1,se])
    return x

def squeeze_excite_block(input1,ratio=4):
    se=GlobalAveragePooling2D()(input1)
    se=Dense(input1._keras_shape[-1]//ratio,activation='relu')(se)
    se=Dense(input1._keras_shape[-1],activation='sigmoid')(se)
    se=Reshape((1,1,input1._keras_shape[-1]))(se)
    finput=Multiply()([input1,se])
    return finput

def spatial_Csqueeze_excite_block(input1,ratio=4):
    squeezeblock=squeeze_excite_block(input1,ratio)
    spatialblock=spatial_squeeze_excite_block(input1)
    finalblock=Add()([squeezeblock,spatialblock])
    return finalblock

# %%
inp = keras.Input((586,128,1))

# conv_1
conv1 = Conv2D(filters=32, kernel_size=3, strides=1, padding='same')(inp)
conv1 = keras.layers.SpatialDropout2D(.2, data_format='channels_last')(conv1)
conv1 = BatchNormalization()(conv1)
conv1 = Activation('relu')(conv1)
conv1 = spatial_Csqueeze_excite_block(conv1)
conv2 = Conv2D(filters=32, kernel_size=4, strides=1, padding='same')(inp)
conv2 = keras.layers.SpatialDropout2D(.2, data_format='channels_last')(conv2)
conv2 = BatchNormalization()(conv2)
conv2 = Activation('relu')(conv2)
conv2 = spatial_Csqueeze_excite_block(conv2)
conv3 = Conv2D(filters=32, kernel_size=5, strides=1, padding='same')(inp)
conv3 = keras.layers.SpatialDropout2D(.2, data_format='channels_last')(conv3)
cconv3 = BatchNormalization()(conv3)
conv3 = Activation('relu')(conv3)
conv3 = spatial_Csqueeze_excite_block(conv3)
concat= Concatenate(axis=-1)([conv1,conv2])
concat = spatial_Csqueeze_excite_block(concat)

#conv31 = Conv2D(64,(1,1))(concat)
#conv31 = BatchNormalization()(conv31)
#conv31= Activation('relu')(conv31)
conv31 = Conv2D(32,kernel_size=3,strides=1,padding='same')(concat)
#conv31= SpatialDropout2D(0.2,data_format='channels_last')(conv31)
conv31 = BatchNormalization()(conv31)
conv31 = Activation('relu')(conv31)
conv31= spatial_Csqueeze_excite_block(conv31)
max_pool31 = keras.layers.MaxPool2D(padding="SAME")(conv31)

##conv32 = Conv2D(64,(1,1))(concat)
#conv32 = BatchNormalization()(conv32)
#conv32= Activation('relu')(conv32)
conv32= Conv2D(32,kernel_size=4,strides=1,padding='same')(concat)
#conv32= SpatialDropout2D(0.2,data_format='channels_last')(conv32)
conv32 = BatchNormalization()(conv32)
conv32 = Activation('relu')(conv32)
conv32=spatial_Csqueeze_excite_block(conv32)
max_pool32 = keras.layers.MaxPool2D(padding="SAME")(conv32)

concat2=Concatenate()([max_pool31,max_pool32])
concat2=spatial_Csqueeze_excite_block(concat2)

conv41= SeparableConv2D(128,kernel_size=3,strides=1,padding='same')(concat2)
#conv41= SpatialDropout2D(0.4,data_format='channels_last')(conv41)
conv41 = BatchNormalization()(conv41)
conv41 = Activation('relu')(conv41)
#conv41=spatial_Csqueeze_excite_block(conv41)
max_pool41 = keras.layers.MaxPool2D(padding="SAME")(conv41)

conv51=SeparableConv2D(256,kernel_size=4,strides=1,padding='same')(concat2)
#conv51= SpatialDropout2D(0.4,data_format='channels_last')(conv51)
conv51 = BatchNormalization()(conv51)
conv51 = Activation('relu')(conv51)
conv51=spatial_Csqueeze_excite_block(conv51)
max_pool51 = keras.layers.MaxPool2D(padding="SAME")(conv51)
concat4=Concatenate()([max_pool51,max_pool41])

avg_pool = GlobalAveragePooling2D()(concat4)
dense10 = keras.layers.Dense(80,activation='sigmoid')(avg_pool)


model = keras.Model(inputs=inp,outputs=dense10)

# %%
dense10.shape[-1]
# Out:
# Dimension(80)

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 586, 128, 1)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 586, 128, 32) 320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 586, 128, 32) 544         input_1[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_1 (SpatialDro (None, 586, 128, 32) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_2 (SpatialDro (None, 586, 128, 32) 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 586, 128, 32) 128         spatial_dropout2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 586, 128, 32) 128         spatial_dropout2d_2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 586, 128, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 586, 128, 32) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 32)           0           activation_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 32)           0           activation_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 8)            264         global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 8)            264         global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 32)           288         dense_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 32)           288         dense_3[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 1, 32)     0           dense_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 586, 128, 1)  33          activation_1[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 1, 32)     0           dense_4[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 586, 128, 1)  33          activation_2[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 586, 128, 32) 0           activation_1[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 586, 128, 32) 0           activation_1[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 586, 128, 32) 0           activation_2[0][0]
#                                                                  reshape_2[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 586, 128, 32) 0           activation_2[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 586, 128, 32) 0           multiply_1[0][0]
#                                                                  multiply_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 586, 128, 32) 0           multiply_3[0][0]
#                                                                  multiply_4[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 586, 128, 64) 0           add_1[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 64)           0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 16)           1040        global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 64)           1088        dense_7[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 1, 1, 64)     0           dense_8[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 586, 128, 1)  65          concatenate_1[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 586, 128, 64) 0           concatenate_1[0][0]
#                                                                  reshape_4[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 586, 128, 64) 0           concatenate_1[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 586, 128, 64) 0           multiply_7[0][0]
#                                                                  multiply_8[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 586, 128, 32) 18464       add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 586, 128, 32) 32800       add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 586, 128, 32) 128         conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 586, 128, 32) 128         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 586, 128, 32) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 586, 128, 32) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 32)           0           activation_4[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_6 (Glo (None, 32)           0           activation_5[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 8)            264         global_average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 8)            264         global_average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 32)           288         dense_9[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 32)           288         dense_11[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 1, 1, 32)     0           dense_10[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 586, 128, 1)  33          activation_4[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 1, 1, 32)     0           dense_12[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 586, 128, 1)  33          activation_5[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 586, 128, 32) 0           activation_4[0][0]
#                                                                  reshape_5[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 586, 128, 32) 0           activation_4[0][0]
#                                                                  conv2d_9[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 586, 128, 32) 0           activation_5[0][0]
#                                                                  reshape_6[0][0]
# __________________________________________________________________________________________________
# multiply_12 (Multiply)          (None, 586, 128, 32) 0           activation_5[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 586, 128, 32) 0           multiply_9[0][0]
#                                                                  multiply_10[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 586, 128, 32) 0           multiply_11[0][0]
#                                                                  multiply_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 293, 64, 32)  0           add_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 293, 64, 32)  0           add_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 293, 64, 64)  0           max_pooling2d_1[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_7 (Glo (None, 64)           0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 16)           1040        global_average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 64)           1088        dense_13[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, 1, 1, 64)     0           dense_14[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 293, 64, 1)   65          concatenate_2[0][0]
# __________________________________________________________________________________________________
# multiply_13 (Multiply)          (None, 293, 64, 64)  0           concatenate_2[0][0]
#                                                                  reshape_7[0][0]
# __________________________________________________________________________________________________
# multiply_14 (Multiply)          (None, 293, 64, 64)  0           concatenate_2[0][0]
#                                                                  conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 293, 64, 64)  0           multiply_13[0][0]
#                                                                  multiply_14[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_2 (SeparableCo (None, 293, 64, 256) 17664       add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 293, 64, 256) 1024        separable_conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 293, 64, 256) 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_8 (Glo (None, 256)          0           activation_7[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 64)           16448       global_average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 256)          16640       dense_15[0][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, 1, 1, 256)    0           dense_16[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 293, 64, 1)   257         activation_7[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_1 (SeparableCo (None, 293, 64, 128) 8896        add_7[0][0]
# __________________________________________________________________________________________________
# multiply_15 (Multiply)          (None, 293, 64, 256) 0           activation_7[0][0]
#                                                                  reshape_8[0][0]
# __________________________________________________________________________________________________
# multiply_16 (Multiply)          (None, 293, 64, 256) 0           activation_7[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 293, 64, 128) 512         separable_conv2d_1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 293, 64, 256) 0           multiply_15[0][0]
#                                                                  multiply_16[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 293, 64, 128) 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 147, 32, 256) 0           add_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 147, 32, 128) 0           activation_6[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 147, 32, 384) 0           max_pooling2d_4[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_9 (Glo (None, 384)          0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 80)           30800       global_average_pooling2d_9[0][0]
# ==================================================================================================
# Total params: 151,607
# Trainable params: 150,583
# Non-trainable params: 1,024
# __________________________________________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
history=model.fit(x_train,y_train,batch_size=24,epochs=26,verbose=1,shuffle=True,validation_split=0.05)
# Out:
# Train on 4249 samples, validate on 224 samples
# Epoch 1/26
# 4249/4249 [==============================] - 120s 28ms/step - loss: 0.1009 - acc: 0.9754 - val_loss: 0.0710 - val_acc: 0.9856
# Epoch 2/26
# 4249/4249 [==============================] - 113s 27ms/step - loss: 0.0687 - acc: 0.9855 - val_loss: 0.0680 - val_acc: 0.9857
# Epoch 3/26
# 4249/4249 [==============================] - 113s 27ms/step - loss: 0.0657 - acc: 0.9855 - val_loss: 0.0651 - val_acc: 0.9858
# Epoch 4/26
# 4249/4249 [==============================] - 113s 27ms/step - loss: 0.0638 - acc: 0.9857 - val_loss: 0.0632 - val_acc: 0.9858
# Epoch 5/26
# 4249/4249 [==============================] - 113s 27ms/step - loss: 0.0617 - acc: 0.9857 - val_loss: 0.0621 - val_acc: 0.9857
# Epoch 6/26
# 4249/4249 [==============================] - 113s 27ms/step - loss: 0.0603 - acc: 0.9857 - val_loss: 0.0616 - val_acc: 0.9858
# Epoch 7/26
# 4249/4249 [==============================] - 113s 27ms/step - loss: 0.0592 - acc: 0.9857 - val_loss: 0.0617 - val_acc: 0.9854
# Epoch 8/26
# 4249/4249 [==============================] - 113s 27ms/step - loss: 0.0576 - acc: 0.9858 - val_loss: 0.0608 - val_acc: 0.9855
# Epoch 9/26
# 4249/4249 [==============================] - 113s 27ms/step - loss: 0.0565 - acc: 0.9858 - val_loss: 0.0580 - val_acc: 0.9857
# Epoch 10/26
# 4249/4249 [==============================] - 113s 27ms/step - loss: 0.0552 - acc: 0.9859 - val_loss: 0.0551 - val_acc: 0.9855
# Epoch 11/26
# 4249/4249 [==============================] - 113s 27ms/step - loss: 0.0541 - acc: 0.9859 - val_loss: 0.0627 - val_acc: 0.9839
# Epoch 12/26
# 4249/4249 [==============================] - 113s 27ms/step - loss: 0.0535 - acc: 0.9860 - val_loss: 0.0517 - val_acc: 0.9859
# Epoch 13/26
# 4249/4249 [==============================] - 113s 27ms/step - loss: 0.0523 - acc: 0.9860 - val_loss: 0.0547 - val_acc: 0.9859
# Epoch 14/26
# 4249/4249 [==============================] - 113s 27ms/step - loss: 0.0512 - acc: 0.9860 - val_loss: 0.0520 - val_acc: 0.9858
# Epoch 15/26
# 4249/4249 [==============================] - 113s 27ms/step - loss: 0.0504 - acc: 0.9862 - val_loss: 0.0521 - val_acc: 0.9859
# Epoch 16/26
# 4249/4249 [==============================] - 113s 26ms/step - loss: 0.0494 - acc: 0.9862 - val_loss: 0.0531 - val_acc: 0.9852
# Epoch 17/26
# 4249/4249 [==============================] - 113s 27ms/step - loss: 0.0487 - acc: 0.9862 - val_loss: 0.0518 - val_acc: 0.9862
# Epoch 18/26
# 4249/4249 [==============================] - 113s 27ms/step - loss: 0.0478 - acc: 0.9864 - val_loss: 0.0517 - val_acc: 0.9860
# Epoch 19/26
# 4249/4249 [==============================] - 113s 27ms/step - loss: 0.0471 - acc: 0.9863 - val_loss: 0.0491 - val_acc: 0.9860
# Epoch 20/26
# 4249/4249 [==============================] - 113s 27ms/step - loss: 0.0463 - acc: 0.9865 - val_loss: 0.0523 - val_acc: 0.9857
# Epoch 21/26
# 4249/4249 [==============================] - 113s 27ms/step - loss: 0.0460 - acc: 0.9865 - val_loss: 0.0500 - val_acc: 0.9864
# Epoch 22/26
# 4249/4249 [==============================] - 113s 27ms/step - loss: 0.0453 - acc: 0.9866 - val_loss: 0.0495 - val_acc: 0.9858
# Epoch 23/26
# 4249/4249 [==============================] - 113s 27ms/step - loss: 0.0444 - acc: 0.9867 - val_loss: 0.0478 - val_acc: 0.9862
# Epoch 24/26
# 4249/4249 [==============================] - 113s 26ms/step - loss: 0.0441 - acc: 0.9869 - val_loss: 0.0517 - val_acc: 0.9857
# Epoch 25/26
# 4249/4249 [==============================] - 112s 26ms/step - loss: 0.0444 - acc: 0.9867 - val_loss: 0.0454 - val_acc: 0.9867
# Epoch 26/26
# 4249/4249 [==============================] - 113s 26ms/step - loss: 0.0430 - acc: 0.9868 - val_loss: 0.0485 - val_acc: 0.9860

# %%
#Important Concept learnt while training:- Too much dropout hurt models performance. Dropout rate is a hyperparameter

# %%
x_train=0
y_train=0

# %%
X_test = np.array(convert_wav_to_image(testdf, [test_path]))
X_test = normalize_dataset(X_test)
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %%
X_test=np.array(X_test).reshape((-1,586,128,1))

# %%
predictions = model.predict(X_test)
# Save predictions in a csv file
testdf[label_columns] = predictions
testdf.to_csv('submission.csv', index=False)
